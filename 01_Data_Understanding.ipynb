# %% [markdown]
# # Smart India Road Accident Forecasting - Data Understanding
#
# This notebook explains the initial dataset and basic EDA steps.

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path('../data/raw/road_accidents.csv')
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()

# %%
year_cols = ['2019 Accidents','2020 Accidents','2021 Accidents','2022 Accidents','2023 Accidents']
df[['State'] + year_cols].head(10)

# %% [markdown]
# ## Next Step
# Run `python -m src.data_preprocessing` from the project root to generate the cleaned datasets.
